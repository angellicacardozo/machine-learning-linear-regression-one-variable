# %%
import numpy as np

# %%
data = np.genfromtxt('ex1data1', delimiter=',')
x = data[:,[0]]
y = data[:,[1]]
# Out:
# array([[  6.1101],
#        [  5.5277],
#        [  8.5186],
#        [  7.0032],
#        [  5.8598],
#        [  8.3829],
#        [  7.4764],
#        [  8.5781],
#        [  6.4862],
#        [  5.0546],
#        [  5.7107],
#        [ 14.164 ],
#        [  5.734 ],
#        [  8.4084],
#        [  5.6407],
#        [  5.3794],
#        [  6.3654],
#        [  5.1301],
#        [  6.4296],
#        [  7.0708],
#        [  6.1891],
#        [ 20.27  ],
#        [  5.4901],
#        [  6.3261],
#        [  5.5649],
#        [ 18.945 ],
#        [ 12.828 ],
#        [ 10.957 ],
#        [ 13.176 ],
#        [ 22.203 ],
#        [  5.2524],
#        [  6.5894],
#        [  9.2482],
#        [  5.8918],
#        [  8.2111],
#        [  7.9334],
#        [  8.0959],
#        [  5.6063],
#        [ 12.836 ],
#        [  6.3534],
#        [  5.4069],
#        [  6.8825],
#        [ 11.708 ],
#        [  5.7737],
#        [  7.8247],
#        [  7.0931],
#        [  5.0702],
# ...

# %%
figure = {'layout': {'xaxis': 'Population', 'yaxis': 'Profit'}}
